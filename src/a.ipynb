# %%
from pathlib import Path
import missingno as msno
import pandas as pd

# %%
    
energy_df = pd.read_csv(Path().absolute().parent/'data'/'raw'/'doi_10.7941_D1N33Q__v6'/'Building_59'/'Bldg59_clean data'/'energy.csv')
energy_df['date'] = pd.to_datetime(energy_df['date']) 
msno.matrix(energy_df.set_index(['date']), freq = 'M')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /home/cdellefemine/HVAC_Control/src/a.ipynb Cella 1 in <cell line: 5>()
#       <a href='vscode-notebook-cell://ssh-remote%2Bsheldon/home/cdellefemine/HVAC_Control/src/a.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> import missingno as msno
#       <a href='vscode-notebook-cell://ssh-remote%2Bsheldon/home/cdellefemine/HVAC_Control/src/a.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> import pandas as pd
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bsheldon/home/cdellefemine/HVAC_Control/src/a.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> energy_df = pd.read_csv(Path().absolute().parent/'data'/'raw'/'doi_10.7941_D1N33Q__v6'/'Building_59'/'Bldg59_clean data'/'energy.csv')
# ...

# %%
train_temp_df = pd.read_csv(Path().absolute().parent/'data'/'cleaned'/'temp'/'train_set_imp.csv')

# %%
train_temp_df
# Out:
#        air_temp_set_1  air_temp_set_2  dew_point_temperature_set_1d  \
# 0           -0.457143       -0.389922                      0.383861
# 1           -0.484096       -0.445431                      0.499453
# 2           -0.476395       -0.445431                      0.550244
# 3           -0.493721       -0.458240                      0.555498
# 4           -0.509123       -0.475320                      0.541487
# ...               ...             ...                           ...
# 41128        1.662481        1.525115                     -0.059243
# 41129        1.756815        1.555004                     -0.306190
# 41130        1.760665        1.640401                     -0.427037
# 41131        1.868475        1.725799                     -0.495342
# 41132        1.941632        1.759957                     -0.600426
#
#        relative_humidity_set_1  solar_radiation_set_1  hp_hws_temp  \
# 0                     0.698938              -0.682362    -1.089893
# ...

# %%
energy_df = pd.read_csv(Path().absolute().parent/'data'/'lbnlbldg59'/'lbnlbldg59.processed'/'LBNLBLDG59'/'clean_Bldg59_2018to2020'/'clean data'/'temp.csv')
energy_df['date'] = pd.to_datetime(energy_df['date'])
#energy_df = energy_df[energy_df['date'] > '2019-04-01'] 
msno.matrix(energy_df.set_index(['date']), freq = 'M')
# Out:
# <AxesSubplot: >

# %%
energy_df = pd.read_csv(Path().absolute().parent/'data'/'lbnlbldg59'/'lbnlbldg59.processed'/'LBNLBLDG59'/'clean_Bldg59_2018to2020'/'clean data'/'energy.csv')
energy_df['date'] = pd.to_datetime(energy_df['date'])
msno.matrix(energy_df.set_index(['date']), freq = 'M')
# Out:
# <AxesSubplot: >

# %%
energy_df = pd.read_csv(Path().absolute().parent/'data'/'lbnlbldg59'/'lbnlbldg59.processed'/'LBNLBLDG59'/'clean_Bldg59_2018to2020'/'clean data'/'zone_temp_exterior.csv')
energy_df['date'] = pd.to_datetime(energy_df['date'])
msno.matrix(energy_df.set_index(['date']))
# Out:
# <AxesSubplot: >
# Si è verificato un arresto anomalo del kernel durante l'esecuzione del codice nella cella attiva o in una cella precedente. Esaminare il codice nelle celle per identificare una possibile causa dell'errore. Per altre informazioni, fare clic su <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a>. Per altri dettagli, vedere Jupyter <a href='command:jupyter.viewOutput'>log</a>.

# %%
energy_df = pd.read_csv(Path().absolute().parent/'data'/'cleaned'/'energy'/'train_set_imp.csv')
energy_df['date'] = pd.to_datetime(energy_df['date'])
msno.matrix(energy_df.set_index(['date']), freq = 'M')
# Out:
# <AxesSubplot: >
